# %%
import numpy as np
from copy import deepcopy
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers,regularizers,metrics,optimizers
import random
import pandas as pd
from scipy.linalg import sqrtm
import pickle
from typing import Any, Callable, Dict, List, Optional, Union
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph
import math
import scipy.stats as st
from scipy.special import comb
from collections import defaultdict

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config=tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.8
config.gpu_options.allow_growth=True
sess=tf.compat.v1.Session(config=config)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train/255
x_test = x_test/255
y_train_onehot=tf.keras.utils.to_categorical(y_train,num_classes=10)
y_test_onehot=tf.keras.utils.to_categorical(y_test,num_classes=10)
y_train=y_train.reshape(50000)

# %%
"""This code is the second part of the code used to generate the redundancy evaluation algorithm's distillation data 
on ResNet-32. Based on the distillation data that has already learned some data features from the first part, by using 
the output of the last hidden layer of ResNet-18 from both the original data and the distillation data, the differences 
in their means and variances are calculated. This allows for fine-tuning of the distillation data, enabling it to 
achieve a high accuracy rate on the ResNet-18 network. This ensures that the distillation data meets the requirement that 
the data used by the evaluation algorithm must be fully learned by the network."""

# %%
initial_lr = 1e-2
epochs = 400
warmup_epochs = 10

# %%
batch=2000

# %%
class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr, total_steps, warmup_steps, warmup_lr=0.0):
        super().__init__()
        self.base_lr = base_lr
        self.total_steps = total_steps
        self.warmup_steps = warmup_steps
        self.warmup_lr = warmup_lr
    def __call__(self, step):
        if step is None:
            step = tf.constant(0)
        step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        total_steps = tf.cast(self.total_steps, tf.float32)
        warmup_percent_done = step / warmup_steps
        learning_rate = tf.where(
            step < warmup_steps,
            self.warmup_lr + (self.base_lr - self.warmup_lr) * warmup_percent_done,
            self.base_lr * 0.5 * (1.0 + tf.cos(math.pi * (step - warmup_steps) / (total_steps - warmup_steps)))
        )
        return learning_rate
    def get_config(self):
        return {
            "base_lr": self.base_lr,
            "total_steps": self.total_steps,
            "warmup_steps": self.warmup_steps,
            "warmup_lr": self.warmup_lr,
        }

# %%
class CustomWeightDecaySGD(tf.keras.optimizers.SGD):
    def __init__(self, weight_decay, **kwargs):
        super().__init__(**kwargs)
        self.weight_decay = weight_decay

    def apply_gradients(self, grads_and_vars, name=None, experimental_aggregate_gradients=True):
        new_grads_and_vars = []
        for (grad, var) in grads_and_vars:
            if ('kernel' in var.name) and ('bn' not in var.name.lower()):
                grad += self.weight_decay * var
            new_grads_and_vars.append((grad, var))
        return super().apply_gradients(new_grads_and_vars, name, experimental_aggregate_gradients)
    def get_config(self):
        return {
            "weight_decay": self.weight_decay,
            **super().get_config(),
        }

# %%
model_R=keras.models.load_model("Res32_cifar10.h5",custom_objects={
        'CustomWeightDecaySGD': CustomWeightDecaySGD,
        'WarmUpCosine': WarmUpCosine
    })

# %%
model_R.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   432         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['batch_normalization_2[0][0]',
#                                                                   're_lu[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['batch_normalization_4[0][0]',
#                                                                   're_lu_2[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['batch_normalization_6[0][0]',
#                                                                   're_lu_4[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 16)   0           ['batch_normalization_8[0][0]',
#                                                                   're_lu_6[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 32, 32, 16)   0           ['add_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2304        ['re_lu_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 32, 32, 16)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   2304        ['re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 16)   0           ['batch_normalization_10[0][0]',
#                                                                   're_lu_8[0][0]']
#
#  re_lu_10 (ReLU)                (None, 32, 32, 16)   0           ['add_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 32)   4608        ['re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 32)  128         ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 16, 16, 32)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 32)   512         ['re_lu_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 32)  128         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  re_lu_12 (ReLU)                (None, 16, 16, 32)   0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 32)  128         ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 16, 16, 32)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 32)  128         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_15[0][0]',
#                                                                   're_lu_12[0][0]']
#
#  re_lu_14 (ReLU)                (None, 16, 16, 32)   0           ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 32)  128         ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 16, 16, 32)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 32)  128         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_17[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  re_lu_16 (ReLU)                (None, 16, 16, 32)   0           ['add_7[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_16[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 32)  128         ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 16, 16, 32)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_17[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 32)  128         ['conv2d_19[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_19[0][0]',
#                                                                   're_lu_16[0][0]']
#
#  re_lu_18 (ReLU)                (None, 16, 16, 32)   0           ['add_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 16, 16, 32)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 32)   9216        ['re_lu_19[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_21[0][0]',
#                                                                   're_lu_18[0][0]']
#
#  re_lu_20 (ReLU)                (None, 16, 16, 32)   0           ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 64)     18432       ['re_lu_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 64)    256         ['conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 8, 8, 64)     0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 64)     2048        ['re_lu_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 64)    256         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 64)    256         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_23[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  re_lu_22 (ReLU)                (None, 8, 8, 64)     0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 64)    256         ['conv2d_25[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 8, 8, 64)     0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 64)    256         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_26[0][0]',
#                                                                   're_lu_22[0][0]']
#
#  re_lu_24 (ReLU)                (None, 8, 8, 64)     0           ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 64)    256         ['conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 8, 8, 64)     0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 64)    256         ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_28[0][0]',
#                                                                   're_lu_24[0][0]']
#
#  re_lu_26 (ReLU)                (None, 8, 8, 64)     0           ['add_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_26[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 64)    256         ['conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 8, 8, 64)     0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_27[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 64)    256         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_30[0][0]',
#                                                                   're_lu_26[0][0]']
#
#  re_lu_28 (ReLU)                (None, 8, 8, 64)     0           ['add_13[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_28[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 64)    256         ['conv2d_31[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 8, 8, 64)     0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 64)     36864       ['re_lu_29[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 64)    256         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_32[0][0]',
#                                                                   're_lu_28[0][0]']
#
#  re_lu_30 (ReLU)                (None, 8, 8, 64)     0           ['add_14[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['re_lu_30[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           650         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 469,370
# Trainable params: 466,906
# Non-trainable params: 2,464
# __________________________________________________________________________________________________

# %%
hidden_layer_model_R = tf.keras.Model(inputs=model_R.input,
                                    outputs=model_R.get_layer('re_lu_30').output)

# %%
s=200
K=10
N=10

# %%
model_R.layers[-2].name
# Out:
# 'global_average_pooling2d'

# %%
def feature_train(x,models,N=N,b=128):
    f=np.zeros((N,batch,b))
    for i in range(10):
        model=models[i]
        layer_outputs =[layer.output for layer in model.layers] 
        activation_model = tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)
        layer=activation_model.predict(x)
        f[i]=layer[-1]
    return f

# %%
def feature_dist(x,models,N=N,b=128):
    x=tf.reshape(x,[s*K,32,32,3])
    for i in range(N):
        model=models[i]
        if i==0:
            f=model(x)
            f=tf.reshape(f,[1,s*K,b])
        else:
            f_i=tf.reshape(model(x),[1,s*K,b])
            f=tf.concat([f,f_i], axis=0)
    return tf.cast(f,dtype=tf.float32)

# %%
def feature(x,L=s*K):
    hidden_layer_model_R_1 = tf.keras.Model(inputs=model_R.input,
                                    outputs=model_R.get_layer('re_lu_30').output)
    X_R_1=hidden_layer_model_R_1.predict(x)
    X_R_1=X_R_1.reshape(L,64*8*8)
    return X_R_1

# %%
def tf_conv(x):
    mean_x = tf.reduce_mean(x, axis=0, keepdims=True)
    mx = tf.matmul(tf.transpose(mean_x), mean_x)
    vx = tf.matmul(tf.transpose(x), x)/tf.cast(tf.shape(x)[0], tf.float32)
    cov_xx = vx - mx
    return cov_xx

# %%
def tf_mean(x):
    return tf.reduce_mean(x, axis=0)

# %%
def loss_DM(x_t,x_s,y_t,y_s,i):
    x_ti=tf.boolean_mask(x_t,tf.equal(y_t,i))
    x_si=tf.boolean_mask(x_s,tf.equal(y_s,i))
    DDD=tf.norm(tf_mean(x_ti)-tf_mean(x_si))
    return DDD

# %%
def loss_cov(x_t,x_s,y_t,y_s,i):
    x_ti=tf.boolean_mask(x_t,tf.equal(y_t,i))
    x_si=tf.boolean_mask(x_s,tf.equal(y_s,i))
    CCC=tf.norm(tf_conv(x_ti)-tf_conv(x_si))
    return CCC

# %%
def loss_c(x_t,x_s):
    cov=tf.norm(tf_conv(x_t)-tf_conv(x_s))
    return cov

# %%
def loss(x_t,x_s,y_t,y_s,lam_1,i):
    dm_l=loss_DM(x_t,x_s,y_t,y_s,i)
    cov_l=loss_cov(x_t,x_s,y_t,y_s,i)
    return dm_l+lam_1*cov_l

# %%
def loss_lam(x_t,x_s,y_t,y_s,lam_1,i):
    dm_l=np.zeros(N)
    cov_l=np.zeros(N)
    class_l=np.zeros(N)
    for i in range(N):
        dm_l[i]=loss_DM(x_t[i],x_s[i],y_t,y_s,i)
        cov_l[i]=loss_cov(x_t[i],x_s[i],y_t,y_s,i)
    dm_l=np.sum(dm_l)
    cov_l=np.sum(cov_l)
    return dm_l+lam_1*cov_l

# %%
def create_balanced_batches(data, labels, num_classes=10, samples_per_class_per_batch=200):
    """This function is used for stratified sampling, 
    extracting the original samples into batches of 
    the same size as the distillation dataset."""
    class_to_indices = defaultdict(list)
    for idx, label in enumerate(labels):
        class_to_indices[label].append(idx)
    for cls in range(num_classes):
        np.random.shuffle(class_to_indices[cls])
    total_per_class = len(class_to_indices[0])
    num_batches = total_per_class // samples_per_class_per_batch
    batches = []
    for batch_idx in range(num_batches):
        batch_indices = []
        for cls in range(num_classes):
            start = batch_idx * samples_per_class_per_batch
            end = start + samples_per_class_per_batch
            batch_indices.extend(class_to_indices[cls][start:end])
        np.random.shuffle(batch_indices)
        batch_data = data[batch_indices]
        batch_labels = labels[batch_indices]
        batches.append((batch_data, batch_labels))
    return batches

# %%
with open('data_dist_10.pkl', 'rb') as f:
    [I,x_train,y_train,x_dist,y_dist]=pickle.load(f)
x_dist=x_dist.numpy()
y_dist=y_dist.numpy()

# %%
lam_1=0.1
y_dist_onehot=tf.keras.utils.to_categorical(y_dist,num_classes=10)

# %%
model_R.evaluate(x_dist,y_dist_onehot)
# Out:
# 63/63 [==============================] - 3s 11ms/step - loss: 1.7108 - accuracy: 0.5010
# [1.7107563018798828, 0.5009999871253967]

# %%
x_dist=tf.Variable(x_dist)

# %%
def dist_2(I,x_dist):
    """
    Distillation data fine-tuning function
    This function directly optimizes the fine-tuning of distillation data x_s.
    By adding a loss term that combines the difference mean and variance for 
    the final hidden layer outputs of the original data and the distillation 
    data, it enables it to maintain the key features of the original data while 
    achieving a high accuracy rate on ResNet-32. 
    """
    for i in range(10):
        lr_schedule = WarmUpCosine(1e-3, 100, 0)
        optimizer=tf.keras.optimizers.Adam(learning_rate=initial_lr)
        NNN=len(y_train)//batch
        t_batch=create_balanced_batches(x_train,y_train)
        for j in range(NNN):
            loss_1=0
            loss_2=0
            x_batch,y_batch=t_batch[j]
            x_batch=tf.cast(x_batch,dtype=tf.float32)
            f_train=feature(x_batch,L=2000)
            x_t=tf.reshape(x_batch,[batch,32*32*3])
            for k in range(4):
                with tf.GradientTape() as tape:
                    tape.watch(x_dist)
                    f_dist_R = hidden_layer_model_R(x_dist)
                    f_dist_R=tf.reshape(f_dist_R,[s*K,64*8*8])
                    x_s=tf.reshape(x_dist,[s*K,32*32*3])
                    loss_r=loss(f_train,f_dist_R,y_batch,y_dist,lam_1,i)
                    loss_x=loss(x_t,x_s,y_batch,y_dist,lam_1,i)
                    loss_=0.1*loss_r+loss_x
                grad = tape.gradient(loss_, x_dist)
                optimizer.apply_gradients(zip([grad], [x_dist]))
                x_dist.assign(tf.clip_by_value(x_dist, 0.0, 1.0))
                loss_1+=loss_x
                loss_2+=loss_r
            if (j+1)%5==0:
                print(loss_1,loss_2)
                x_dist_=x_dist.numpy()
                a2=model_R.evaluate(x_dist_,y_dist_onehot)
        with open('data_dist_ResNet_32.pkl', 'wb') as f:
            pickle.dump([x_train,y_train,x_dist,y_dist],f)
    return x_dist

# %%
x_dist=dist_2(I,x_dist)
# Out:
# tf.Tensor(14.263944, shape=(), dtype=float32) tf.Tensor(430.98892, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4461 - accuracy: 0.5755
# tf.Tensor(14.758696, shape=(), dtype=float32) tf.Tensor(399.5118, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4463 - accuracy: 0.5755
# tf.Tensor(13.971576, shape=(), dtype=float32) tf.Tensor(403.65723, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4461 - accuracy: 0.5750
# tf.Tensor(11.308893, shape=(), dtype=float32) tf.Tensor(401.24908, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4448 - accuracy: 0.5755
# tf.Tensor(9.819644, shape=(), dtype=float32) tf.Tensor(405.16302, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4463 - accuracy: 0.5755
# tf.Tensor(12.532318, shape=(), dtype=float32) tf.Tensor(462.42743, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.1401 - accuracy: 0.6600
# tf.Tensor(11.745255, shape=(), dtype=float32) tf.Tensor(433.40594, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.1414 - accuracy: 0.6605
# tf.Tensor(10.147327, shape=(), dtype=float32) tf.Tensor(390.06616, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.1412 - accuracy: 0.6600
# tf.Tensor(11.575684, shape=(), dtype=float32) tf.Tensor(407.44254, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.1424 - accuracy: 0.6600
# tf.Tensor(10.2525215, shape=(), dtype=float32) tf.Tensor(404.39447, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.1409 - accuracy: 0.6605
# tf.Tensor(11.521872, shape=(), dtype=float32) tf.Tensor(500.8683, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0114 - accuracy: 0.7070
# tf.Tensor(12.211094, shape=(), dtype=float32) tf.Tensor(461.7304, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0135 - accuracy: 0.7055
# tf.Tensor(8.41275, shape=(), dtype=float32) tf.Tensor(457.99768, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0124 - accuracy: 0.7060
# tf.Tensor(10.310326, shape=(), dtype=float32) tf.Tensor(453.23303, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0144 - accuracy: 0.7050
# tf.Tensor(13.973921, shape=(), dtype=float32) tf.Tensor(454.7349, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0134 - accuracy: 0.7065
# tf.Tensor(13.817055, shape=(), dtype=float32) tf.Tensor(488.82007, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9204 - accuracy: 0.7395
# tf.Tensor(14.442116, shape=(), dtype=float32) tf.Tensor(488.90936, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9179 - accuracy: 0.7410
# tf.Tensor(11.455301, shape=(), dtype=float32) tf.Tensor(474.63617, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9142 - accuracy: 0.7420
# tf.Tensor(10.837603, shape=(), dtype=float32) tf.Tensor(476.28043, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9196 - accuracy: 0.7400
# tf.Tensor(11.469542, shape=(), dtype=float32) tf.Tensor(474.386, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9166 - accuracy: 0.7405
# tf.Tensor(10.659559, shape=(), dtype=float32) tf.Tensor(445.22467, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8188 - accuracy: 0.7780
# tf.Tensor(9.270127, shape=(), dtype=float32) tf.Tensor(408.9978, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8165 - accuracy: 0.7780
# tf.Tensor(9.407762, shape=(), dtype=float32) tf.Tensor(389.59534, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8163 - accuracy: 0.7785
# tf.Tensor(9.355447, shape=(), dtype=float32) tf.Tensor(391.09177, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8169 - accuracy: 0.7785
# tf.Tensor(7.4925117, shape=(), dtype=float32) tf.Tensor(382.11008, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8186 - accuracy: 0.7785
# tf.Tensor(11.819626, shape=(), dtype=float32) tf.Tensor(498.17163, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7320 - accuracy: 0.8060
# tf.Tensor(10.9488125, shape=(), dtype=float32) tf.Tensor(488.44168, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7248 - accuracy: 0.8080
# tf.Tensor(9.938452, shape=(), dtype=float32) tf.Tensor(438.45572, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7274 - accuracy: 0.8085
# tf.Tensor(10.8381, shape=(), dtype=float32) tf.Tensor(426.84024, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7269 - accuracy: 0.8070
# tf.Tensor(13.333128, shape=(), dtype=float32) tf.Tensor(456.9757, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7301 - accuracy: 0.8065
# tf.Tensor(9.740889, shape=(), dtype=float32) tf.Tensor(319.94373, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7045 - accuracy: 0.8145
# tf.Tensor(11.59491, shape=(), dtype=float32) tf.Tensor(313.845, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7045 - accuracy: 0.8145
# tf.Tensor(8.605032, shape=(), dtype=float32) tf.Tensor(297.68274, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7048 - accuracy: 0.8140
# tf.Tensor(7.989104, shape=(), dtype=float32) tf.Tensor(291.98438, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7060 - accuracy: 0.8135
# tf.Tensor(10.017522, shape=(), dtype=float32) tf.Tensor(291.85226, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7055 - accuracy: 0.8145
# tf.Tensor(12.968919, shape=(), dtype=float32) tf.Tensor(439.7315, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3093 - accuracy: 0.9045
# tf.Tensor(11.435877, shape=(), dtype=float32) tf.Tensor(394.4846, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3064 - accuracy: 0.9055
# tf.Tensor(15.438728, shape=(), dtype=float32) tf.Tensor(422.87433, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3091 - accuracy: 0.9040
# tf.Tensor(9.972614, shape=(), dtype=float32) tf.Tensor(380.68127, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3073 - accuracy: 0.9060
# tf.Tensor(9.771117, shape=(), dtype=float32) tf.Tensor(391.43475, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3077 - accuracy: 0.9045
# tf.Tensor(11.446806, shape=(), dtype=float32) tf.Tensor(387.83102, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2318 - accuracy: 0.9300
# tf.Tensor(12.738129, shape=(), dtype=float32) tf.Tensor(341.2977, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2295 - accuracy: 0.9300
# tf.Tensor(10.753893, shape=(), dtype=float32) tf.Tensor(332.4713, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2329 - accuracy: 0.9280
# tf.Tensor(9.83571, shape=(), dtype=float32) tf.Tensor(322.17358, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2295 - accuracy: 0.9305
# tf.Tensor(8.823386, shape=(), dtype=float32) tf.Tensor(311.3756, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2299 - accuracy: 0.9300
# tf.Tensor(12.128182, shape=(), dtype=float32) tf.Tensor(463.10873, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0713 - accuracy: 0.9805
# tf.Tensor(11.582865, shape=(), dtype=float32) tf.Tensor(389.0775, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0700 - accuracy: 0.9810
# tf.Tensor(11.750584, shape=(), dtype=float32) tf.Tensor(390.6914, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0713 - accuracy: 0.9800
# tf.Tensor(10.455237, shape=(), dtype=float32) tf.Tensor(379.40643, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0707 - accuracy: 0.9810
# tf.Tensor(10.666342, shape=(), dtype=float32) tf.Tensor(369.60025, shape=(), dtype=float32)
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0715 - accuracy: 0.9800

# %%
plt.imshow(x_dist[20])
print(y_dist[20])
# Out:
# 2.0

# %%
plt.imshow(x_dist[s])
print(y_dist[s])
# Out:
# 5.0

# %%
m=5
plt.imshow(x_dist[m])
print(y_dist[m])
# Out:
# 5.0

# %%
m=4
plt.imshow(x_dist[m])
print(y_dist[m])
# Out:
# 6.0

# %%
x_dist=tf.reshape(x_dist,[s*K,32,32,3])

# %%
with open('data_dist_ResNet_32.pkl', 'wb') as f:
    pickle.dump([x_dist,y_dist],f)

# %%
a1=model_R.evaluate(x_dist,y_dist_onehot)
# Out:
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0715 - accuracy: 0.9800
