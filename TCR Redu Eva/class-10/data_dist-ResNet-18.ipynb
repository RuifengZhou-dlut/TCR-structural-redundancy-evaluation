# %%
import numpy as np
from copy import deepcopy
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers,regularizers,metrics,optimizers
import random
import pandas as pd
from scipy.linalg import sqrtm
import pickle
from typing import Any, Callable, Dict, List, Optional, Union
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph
import math
import scipy.stats as st
from scipy.special import comb
from collections import defaultdict

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
config=tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.8
config.gpu_options.allow_growth=True
sess=tf.compat.v1.Session(config=config)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train/255
x_test = x_test/255
y_train_onehot=tf.keras.utils.to_categorical(y_train,num_classes=10)
y_test_onehot=tf.keras.utils.to_categorical(y_test,num_classes=10)
y_train=y_train.reshape(50000)

# %%
"""This code is the second part of the code used to generate the redundancy evaluation algorithm's distillation data 
on ResNet-18. Based on the distillation data that has already learned some data features from the first part, by using 
the output of the last hidden layer of ResNet-18 from both the original data and the distillation data, the differences 
in their means and variances are calculated. This allows for fine-tuning of the distillation data, enabling it to 
achieve a high accuracy rate on the ResNet-18 network. This ensures that the distillation data meets the requirement that 
the data used by the evaluation algorithm must be fully learned by the network."""

# %%
initial_lr = 1e-2
epochs = 400
warmup_epochs = 10

# %%
batch=2000

# %%
class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr, total_steps, warmup_steps, warmup_lr=0.0):
        super().__init__()
        self.base_lr = base_lr
        self.total_steps = total_steps
        self.warmup_steps = warmup_steps
        self.warmup_lr = warmup_lr
    def __call__(self, step):
        if step is None:
            step = tf.constant(0)
        step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        total_steps = tf.cast(self.total_steps, tf.float32)
        warmup_percent_done = step / warmup_steps
        learning_rate = tf.where(
            step < warmup_steps,
            self.warmup_lr + (self.base_lr - self.warmup_lr) * warmup_percent_done,
            self.base_lr * 0.5 * (1.0 + tf.cos(math.pi * (step - warmup_steps) / (total_steps - warmup_steps)))
        )
        return learning_rate
    def get_config(self):
        return {
            "base_lr": self.base_lr,
            "total_steps": self.total_steps,
            "warmup_steps": self.warmup_steps,
            "warmup_lr": self.warmup_lr,
        }

# %%
class CustomWeightDecaySGD(tf.keras.optimizers.SGD):
    def __init__(self, weight_decay, **kwargs):
        super().__init__(**kwargs)
        self.weight_decay = weight_decay

    def apply_gradients(self, grads_and_vars, name=None, experimental_aggregate_gradients=True):
        new_grads_and_vars = []
        for (grad, var) in grads_and_vars:
            if ('kernel' in var.name) and ('bn' not in var.name.lower()):
                grad += self.weight_decay * var
            new_grads_and_vars.append((grad, var))
        return super().apply_gradients(new_grads_and_vars, name, experimental_aggregate_gradients)
    def get_config(self):
        return {
            "weight_decay": self.weight_decay,
            **super().get_config(),
        }

# %%
model_R=keras.models.load_model("Res18_cifar10.h5",custom_objects={
        'CustomWeightDecaySGD': CustomWeightDecaySGD,
        'WarmUpCosine': WarmUpCosine
    })

# %%
model_R.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   1728        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 32, 32, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 64)   36864       ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 32, 32, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   36864       ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   're_lu[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 32, 32, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36864       ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 32, 32, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   36864       ['re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   're_lu_2[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 32, 32, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  73728       ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 16, 16, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  147456      ['re_lu_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  8192        ['re_lu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 16, 16, 128)  0           ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 128)  147456      ['re_lu_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 16, 16, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  147456      ['re_lu_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_9[0][0]',
#                                                                   're_lu_6[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 16, 16, 128)  0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    294912      ['re_lu_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_9 (ReLU)                 (None, 8, 8, 256)    0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    589824      ['re_lu_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 256)    32768       ['re_lu_8[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 256)    0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  re_lu_10 (ReLU)                (None, 8, 8, 256)    0           ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 256)    589824      ['re_lu_10[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 256)    589824      ['re_lu_11[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 8, 8, 256)    0           ['batch_normalization_14[0][0]',
#                                                                   're_lu_10[0][0]']
#
#  re_lu_12 (ReLU)                (None, 8, 8, 256)    0           ['add_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 4, 4, 512)    1179648     ['re_lu_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 4, 4, 512)    0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 4, 4, 512)    2359296     ['re_lu_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 4, 4, 512)    131072      ['re_lu_12[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_17[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 4, 4, 512)    0           ['batch_normalization_16[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  re_lu_14 (ReLU)                (None, 4, 4, 512)    0           ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 4, 4, 512)    2359296     ['re_lu_14[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 4, 4, 512)    0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 4, 4, 512)    2359296     ['re_lu_15[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_19[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 4, 4, 512)    0           ['batch_normalization_19[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  re_lu_16 (ReLU)                (None, 4, 4, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['re_lu_16[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           5130        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 11,183,562
# Trainable params: 11,173,962
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
hidden_layer_model_R = tf.keras.Model(inputs=model_R.input,
                                    outputs=model_R.get_layer('global_average_pooling2d').output)

# %%
s=200
K=10
N=10

# %%
model_R.layers[-2].name
# Out:
# 'global_average_pooling2d'

# %%
def feature_train(x,models,N=N,b=128):
    f=np.zeros((N,batch,b))
    for i in range(10):
        model=models[i]
        layer_outputs =[layer.output for layer in model.layers] 
        activation_model = tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)
        layer=activation_model.predict(x)
        f[i]=layer[-2]
    return f

# %%
def feature_dist(x,models,N=N,b=128):
    x=tf.reshape(x,[s*K,32,32,3])
    for i in range(N):
        model=models[i]
        if i==0:
            f=model(x)
            f=tf.reshape(f,[1,s*K,b])
        else:
            f_i=tf.reshape(model(x),[1,s*K,b])
            f=tf.concat([f,f_i], axis=0)
    return tf.cast(f,dtype=tf.float32)

# %%
def feature(x,L=s*K):
    hidden_layer_model_R = tf.keras.Model(inputs=model_R.input,
                                    outputs=model_R.get_layer('global_average_pooling2d').output)
    X_R=hidden_layer_model_R.predict(x)
    X_R=X_R.reshape(L,512)
    return X_R

# %%
def tf_conv(x):
    mean_x = tf.reduce_mean(x, axis=0, keepdims=True)
    mx = tf.matmul(tf.transpose(mean_x), mean_x)
    vx = tf.matmul(tf.transpose(x), x)/tf.cast(tf.shape(x)[0], tf.float32)
    cov_xx = vx - mx
    return cov_xx

# %%
def tf_mean(x):
    return tf.reduce_mean(x, axis=0)

# %%
def loss_DM(x_t,x_s,y_t,y_s,i):
    x_ti=tf.boolean_mask(x_t,tf.equal(y_t,i))
    x_si=tf.boolean_mask(x_s,tf.equal(y_s,i))
    DDD=tf.norm(tf_mean(x_ti)-tf_mean(x_si))
    return DDD

# %%
def loss_cov(x_t,x_s,y_t,y_s,i):
    x_ti=tf.boolean_mask(x_t,tf.equal(y_t,i))
    x_si=tf.boolean_mask(x_s,tf.equal(y_s,i))
    CCC=tf.norm(tf_conv(x_ti)-tf_conv(x_si))
    return CCC

# %%
def loss_c(x_t,x_s):
    cov=tf.norm(tf_conv(x_t)-tf_conv(x_s))
    return cov

# %%
def loss(x_t,x_s,y_t,y_s,lam_1,i):
    dm_l=loss_DM(x_t,x_s,y_t,y_s,i)
    cov_l=loss_cov(x_t,x_s,y_t,y_s,i)
    #class_l=loss_class(x_s,y_s)
    #cos_l=loss_cos(x_t,x_s,y_t,y_s)
    #return dm_l+lam_1*cov_l+lam_2*cos_l
    return dm_l+lam_1*cov_l

# %%
def create_balanced_batches(data, labels, num_classes=10, samples_per_class_per_batch=200):
    """This function is used for stratified sampling, 
    extracting the original samples into batches of 
    the same size as the distillation dataset."""
    class_to_indices = defaultdict(list)
    for idx, label in enumerate(labels):
        class_to_indices[label].append(idx)
    for cls in range(num_classes):
        np.random.shuffle(class_to_indices[cls])
    total_per_class = len(class_to_indices[0])
    num_batches = total_per_class // samples_per_class_per_batch
    batches = []
    for batch_idx in range(num_batches):
        batch_indices = []
        for cls in range(num_classes):
            start = batch_idx * samples_per_class_per_batch
            end = start + samples_per_class_per_batch
            batch_indices.extend(class_to_indices[cls][start:end])
        np.random.shuffle(batch_indices)
        batch_data = data[batch_indices]
        batch_labels = labels[batch_indices]
        batches.append((batch_data, batch_labels))
    return batches

# %%
with open('data_dist_10.pkl', 'rb') as f:
    [I,x_train,y_train,x_dist,y_dist]=pickle.load(f)

# %%
lam_1=0.1
y_dist_onehot=tf.keras.utils.to_categorical(y_dist,num_classes=10)

# %%
model_R.evaluate(x_dist,y_dist_onehot)
# Out:
# 63/63 [==============================] - 3s 8ms/step - loss: 1.7195 - accuracy: 0.4815
# [1.7194881439208984, 0.4814999997615814]

# %%
x_dist=tf.Variable(x_dist)

# %%
def dist_2(I,x_dist):
    """
    Distillation data fine-tuning function
    This function directly optimizes the fine-tuning of distillation data x_s.
    By adding a loss term that combines the difference mean and variance for 
    the final hidden layer outputs of the original data and the distillation 
    data, it enables it to maintain the key features of the original data while 
    achieving a high accuracy rate on ResNet-18. 
    """
    for i in range(10):
        lr_schedule = WarmUpCosine(1e-3, 100, 0)
        optimizer=tf.keras.optimizers.Adam(learning_rate=initial_lr)
        NNN=len(y_train)//batch
        t_batch=create_balanced_batches(x_train,y_train)
        for j in range(NNN):
            loss_1=0
            loss_2=0
            x_batch,y_batch=t_batch[j]
            x_batch=tf.cast(x_batch,dtype=tf.float32)
            f_train=feature(x_batch,L=2000)
            x_t=tf.reshape(x_batch,[batch,32*32*3])
            for k in range(4):
                with tf.GradientTape() as tape:
                    tape.watch(x_dist)
                    f_dist_R = hidden_layer_model_R(x_dist)
                    f_dist_R=tf.reshape(f_dist_R,[s*K,512])
                    x_s=tf.reshape(x_dist,[s*K,32*32*3])
                    loss_r=loss(f_train,f_dist_R,y_batch,y_dist,lam_1,i)
                    loss_x=loss(x_t,x_s,y_batch,y_dist,lam_1,i)
                    loss_=0.1*loss_r+loss_x
                grad = tape.gradient(loss_, x_dist)
                optimizer.apply_gradients(zip([grad], [x_dist]))
                x_dist.assign(tf.clip_by_value(x_dist, 0.0, 1.0))
                loss_1+=loss_x
                loss_2+=loss_r
            if (j+1)%5==0:
                print(loss_1,loss_2)
                x_dist_=x_dist.numpy()
                a2=model_R.evaluate(x_dist_,y_dist_onehot)
        with open('data_dist_ResNet_18.pkl', 'wb') as f:
            pickle.dump([x_train,y_train,x_dist,y_dist],f)
    return x_dist

# %%
x_dist=dist_2(I,x_dist)
# Out:
# tf.Tensor(12.276424, shape=(), dtype=float32) tf.Tensor(4.369295, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.4991 - accuracy: 0.5510
# tf.Tensor(9.092182, shape=(), dtype=float32) tf.Tensor(3.187866, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.4988 - accuracy: 0.5510
# tf.Tensor(11.792212, shape=(), dtype=float32) tf.Tensor(2.475286, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.4988 - accuracy: 0.5510
# tf.Tensor(9.459745, shape=(), dtype=float32) tf.Tensor(2.653481, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.4989 - accuracy: 0.5510
# tf.Tensor(9.827768, shape=(), dtype=float32) tf.Tensor(2.4958382, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.4987 - accuracy: 0.5510
# tf.Tensor(12.19043, shape=(), dtype=float32) tf.Tensor(2.4069242, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.1727 - accuracy: 0.6415
# tf.Tensor(11.477661, shape=(), dtype=float32) tf.Tensor(2.0072296, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.1726 - accuracy: 0.6415
# tf.Tensor(9.671244, shape=(), dtype=float32) tf.Tensor(2.1582658, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 1.1726 - accuracy: 0.6415
# tf.Tensor(9.976378, shape=(), dtype=float32) tf.Tensor(2.5712974, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.1725 - accuracy: 0.6415
# tf.Tensor(9.925438, shape=(), dtype=float32) tf.Tensor(1.5196525, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.1725 - accuracy: 0.6415
# tf.Tensor(12.464424, shape=(), dtype=float32) tf.Tensor(4.3349915, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 1.0037 - accuracy: 0.7005
# tf.Tensor(14.504723, shape=(), dtype=float32) tf.Tensor(3.2298486, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 1.0034 - accuracy: 0.7005
# tf.Tensor(9.535672, shape=(), dtype=float32) tf.Tensor(3.1596391, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.0035 - accuracy: 0.7005
# tf.Tensor(9.349253, shape=(), dtype=float32) tf.Tensor(3.2220001, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.0042 - accuracy: 0.6995
# tf.Tensor(10.16456, shape=(), dtype=float32) tf.Tensor(3.6507773, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 1.0039 - accuracy: 0.7005
# tf.Tensor(11.0356455, shape=(), dtype=float32) tf.Tensor(3.577002, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.8385 - accuracy: 0.7635
# tf.Tensor(11.094048, shape=(), dtype=float32) tf.Tensor(3.202651, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.8398 - accuracy: 0.7630
# tf.Tensor(12.20421, shape=(), dtype=float32) tf.Tensor(2.9225, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8386 - accuracy: 0.7635
# tf.Tensor(9.852802, shape=(), dtype=float32) tf.Tensor(3.0808372, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8389 - accuracy: 0.7635
# tf.Tensor(11.330607, shape=(), dtype=float32) tf.Tensor(2.932702, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8385 - accuracy: 0.7635
# tf.Tensor(11.731279, shape=(), dtype=float32) tf.Tensor(3.1604643, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.7095 - accuracy: 0.8105
# tf.Tensor(8.656437, shape=(), dtype=float32) tf.Tensor(2.6750598, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.7089 - accuracy: 0.8110
# tf.Tensor(8.561122, shape=(), dtype=float32) tf.Tensor(2.9872403, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7101 - accuracy: 0.8100
# tf.Tensor(7.6196475, shape=(), dtype=float32) tf.Tensor(2.4575837, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7087 - accuracy: 0.8110
# tf.Tensor(9.572556, shape=(), dtype=float32) tf.Tensor(2.8433454, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7088 - accuracy: 0.8110
# tf.Tensor(10.58482, shape=(), dtype=float32) tf.Tensor(4.1238613, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6589 - accuracy: 0.8305
# tf.Tensor(9.12381, shape=(), dtype=float32) tf.Tensor(3.5224607, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6587 - accuracy: 0.8310
# tf.Tensor(10.807748, shape=(), dtype=float32) tf.Tensor(2.9306388, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6584 - accuracy: 0.8310
# tf.Tensor(11.338256, shape=(), dtype=float32) tf.Tensor(3.4557295, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6588 - accuracy: 0.8305
# tf.Tensor(11.30079, shape=(), dtype=float32) tf.Tensor(3.2304497, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6573 - accuracy: 0.8315
# tf.Tensor(10.547181, shape=(), dtype=float32) tf.Tensor(2.615096, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6384 - accuracy: 0.8370
# tf.Tensor(9.395248, shape=(), dtype=float32) tf.Tensor(2.7247787, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6384 - accuracy: 0.8370
# tf.Tensor(7.983762, shape=(), dtype=float32) tf.Tensor(2.4864323, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6383 - accuracy: 0.8370
# tf.Tensor(8.75606, shape=(), dtype=float32) tf.Tensor(2.359723, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6384 - accuracy: 0.8370
# tf.Tensor(10.090825, shape=(), dtype=float32) tf.Tensor(2.3446438, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6383 - accuracy: 0.8370
# tf.Tensor(10.499666, shape=(), dtype=float32) tf.Tensor(2.9111438, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2501 - accuracy: 0.9315
# tf.Tensor(10.802652, shape=(), dtype=float32) tf.Tensor(2.4519897, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2500 - accuracy: 0.9315
# tf.Tensor(11.794496, shape=(), dtype=float32) tf.Tensor(2.6396575, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2504 - accuracy: 0.9315
# tf.Tensor(9.4235115, shape=(), dtype=float32) tf.Tensor(2.4235659, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2497 - accuracy: 0.9315
# tf.Tensor(10.488922, shape=(), dtype=float32) tf.Tensor(2.7707407, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2500 - accuracy: 0.9315
# tf.Tensor(9.650512, shape=(), dtype=float32) tf.Tensor(2.9630263, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2055 - accuracy: 0.9445
# tf.Tensor(9.83547, shape=(), dtype=float32) tf.Tensor(2.546089, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2051 - accuracy: 0.9445
# tf.Tensor(9.584397, shape=(), dtype=float32) tf.Tensor(2.8181276, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2049 - accuracy: 0.9445
# tf.Tensor(9.272598, shape=(), dtype=float32) tf.Tensor(3.5248477, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2051 - accuracy: 0.9445
# tf.Tensor(8.379688, shape=(), dtype=float32) tf.Tensor(2.7538328, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2050 - accuracy: 0.9445
# tf.Tensor(11.007169, shape=(), dtype=float32) tf.Tensor(2.5727258, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0167 - accuracy: 1.0000
# tf.Tensor(10.757816, shape=(), dtype=float32) tf.Tensor(2.8729248, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 1.0000
# tf.Tensor(11.355533, shape=(), dtype=float32) tf.Tensor(1.8981342, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0167 - accuracy: 1.0000
# tf.Tensor(11.206242, shape=(), dtype=float32) tf.Tensor(2.1136823, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0167 - accuracy: 1.0000
# tf.Tensor(10.716564, shape=(), dtype=float32) tf.Tensor(2.6795106, shape=(), dtype=float32)
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 1.0000

# %%
plt.imshow(x_dist[0])
print(y_dist[0])
# Out:
# tf.Tensor(2.0, shape=(), dtype=float64)

# %%
plt.imshow(x_dist[s])
print(y_dist[s])
# Out:
# tf.Tensor(5.0, shape=(), dtype=float64)

# %%
m=5
plt.imshow(x_dist[m])
print(y_dist[m])
# Out:
# tf.Tensor(5.0, shape=(), dtype=float64)

# %%
m=4
plt.imshow(x_dist[m])
print(y_dist[m])
# Out:
# tf.Tensor(6.0, shape=(), dtype=float64)

# %%
x_dist=tf.reshape(x_dist,[s*K,32,32,3])

# %%
with open('data_dist_ResNet_18.pkl', 'wb') as f:
    pickle.dump([x_dist,y_dist],f)

# %%
a1=model_R.evaluate(x_dist,y_dist_onehot)
# Out:
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 1.0000
