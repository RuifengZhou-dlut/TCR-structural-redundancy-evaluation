# %%
import numpy as np
from copy import deepcopy
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers,regularizers,metrics,optimizers
import random
import pandas as pd
from scipy.linalg import sqrtm
import pickle
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import math

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
config=tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.8
config.gpu_options.allow_growth=True
sess=tf.compat.v1.Session(config=config)

# %%
"""
This code is used to train VGGNet-16 using the complete CIFAR-10 dataset. 
It employs an explicit Weight Decay SGD optimizer along with WarmUp + 
Cosine Annealing Learning Rate Scheduler, and enhances the generalization 
ability of the trained network through data augmentation.
"""

# %%
num_classes = 3
initial_lr = 0.1
weight_decay = 1e-4
epochs = 200
warmup_epochs = 5
batch_size = 32
image_size = 32

# %%
with open('data.pkl', 'rb') as f:
    [x_train,y_train,x_test,y_test]=pickle.load(f)
y_train_onehot=tf.keras.utils.to_categorical(y_train,num_classes=3)
y_test_onehot=tf.keras.utils.to_categorical(y_test,num_classes=3)

# %%
NN_16=[64,64,128,128,256,256,256,512,512,512,512,512,512]

# %%
def build_vggnet16(NN,input_shape=(32,32,3),num_class=3):
    model = keras.models.Sequential()
    model.add(layers.Conv2D(filters=NN[0], kernel_size=(3, 3), padding='same'
                            ,input_shape=input_shape,use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[1], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    
    #2
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Conv2D(NN[2], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[3], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    #5
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Conv2D(NN[4], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[5], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization()) 
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[6], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization()) 
    model.add(tf.keras.layers.Activation('relu'))
    #10
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Conv2D(NN[7], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[8], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[9], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    #15
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Conv2D(NN[10], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[11], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Conv2D(NN[12], (3, 3), padding='same',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    #
    #25
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(NN[12]))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Dense(NN[12]))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(layers.Dense(num_class,activation='softmax'))
    return model
model = build_vggnet16(NN_16)

# %%
decay_vars = []
no_decay_vars = []
for var in model.trainable_variables:
    if 'kernel' in var.name and 'bn' not in var.name.lower():
        decay_vars.append(var)
    else:
        no_decay_vars.append(var)

# %%
class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
   WarmUp + Cosine Annealing Learning Rate Scheduler 
   This scheduler divides the training process into two stages:
   1) Warm-up stage (step < warmup_steps):
   The learning rate linearly increases from warmup_lr to base_lr, 
   aiming to alleviate the instability of gradients or excessive 
   parameter updates at the beginning of training, thereby enhancing 
   the stability of the training process.
   2) Cosine Annealing stage (step >= warmup_steps):
   The learning rate smoothly decays from base_lr to a value close 
   to 0 according to the cosine function, which is helpful for 
   conducting more precise parameter search in the later stage of 
   training and improving the final convergence performance. 
   """
    def __init__(self, base_lr, total_steps, warmup_steps, warmup_lr=0.0):
        """
        Parameter description:
        - base_lr: The maximum learning rate to be used after the warm-up period
        - total_steps: The total number of steps for training (epochs × steps_per_epoch)
        - warmup_steps: The number of steps in the warm-up phase
        - warmup_lr: The initial learning rate for warm-up, default is 0
        """
        super().__init__()
        self.base_lr = base_lr
        self.total_steps = total_steps
        self.warmup_steps = warmup_steps
        self.warmup_lr = warmup_lr
    def __call__(self, step):
        if step is None:
            step = tf.constant(0)
        step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        total_steps = tf.cast(self.total_steps, tf.float32)
        warmup_percent_done = step / warmup_steps
        learning_rate = tf.where(
            step < warmup_steps,
            self.warmup_lr + (self.base_lr - self.warmup_lr) * warmup_percent_done,
            self.base_lr * 0.5 * (1.0 + tf.cos(math.pi * (step - warmup_steps) / (total_steps - warmup_steps)))
        )
        return learning_rate
    def get_config(self):
        return {
            "base_lr": self.base_lr,
            "total_steps": self.total_steps,
            "warmup_steps": self.warmup_steps,
            "warmup_lr": self.warmup_lr,
        }
total_steps = epochs * (x_train.shape[0] // batch_size)
warmup_steps = warmup_epochs * (x_train.shape[0] // batch_size)
lr_schedule = WarmUpCosine(initial_lr, total_steps, warmup_steps)

# %%
class CustomWeightDecaySGD(tf.keras.optimizers.SGD):
    """
    SGD optimizer with explicit Weight Decay (Decoupled Weight Decay) 
    This optimizer, based on the standard SGD, manually applies weight 
    decay to the parameters, instead of achieving it through the L2 
    regularization term in the loss. This "decoupled weight decay"
    is in line with the idea of AdamW/SGDW and can avoid the problem 
    that weight decay is indirectly scaled by factors such as learning 
    rate and momentum. 
    """
    def __init__(self, weight_decay, **kwargs):
        """
        Parameter description:
        - weight_decay: Weight decay coefficient (usually ranging from 1e-4 to 1e-2)
        - **kwargs: Other parameters are directly passed to tf.keras.optimizers.SGD,
        such as learning_rate, momentum, nesterov, etc. 
        """
        super().__init__(**kwargs)
        self.weight_decay = weight_decay
    def apply_gradients(self, grads_and_vars, name=None, experimental_aggregate_gradients=True):
        super().apply_gradients(grads_and_vars, name, experimental_aggregate_gradients)
        for grad, var in grads_and_vars:
            if ('kernel' in var.name) and ('bn' not in var.name.lower()):
                var.assign_sub(self.weight_decay * var)
    def get_config(self):
        config = super().get_config()
        config.update({
            "weight_decay": float(self.weight_decay),  # 确保是float
        })
        return config
optimizer = CustomWeightDecaySGD(
    weight_decay=weight_decay,
    learning_rate=lr_schedule,
    momentum=0.9,
    nesterov=True
)

# %%
loss_fn=tf.keras.losses.CategoricalCrossentropy()
model.compile(
    optimizer=optimizer,
    loss=loss_fn,
    metrics=['accuracy']
)

# %%
datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)  # randomly flip images
        # (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# %%
model.fit(datagen.flow(x_train, y_train_onehot,batch_size=batch_size),
                            steps_per_epoch=x_train.shape[0] // batch_size,
                            epochs=epochs,
                            validation_data=(x_test, y_test_onehot),verbose=2)
# Out:
# Epoch 1/200
# 93/93 - 7s - loss: 1.0353 - accuracy: 0.5256 - val_loss: 1.4336 - val_accuracy: 0.3350 - 7s/epoch - 76ms/step
# Epoch 2/200
# 93/93 - 2s - loss: 1.0586 - accuracy: 0.5735 - val_loss: 623.9218 - val_accuracy: 0.3333 - 2s/epoch - 22ms/step
# Epoch 3/200
# 93/93 - 2s - loss: 1.2184 - accuracy: 0.5081 - val_loss: 7.8481 - val_accuracy: 0.3270 - 2s/epoch - 22ms/step
# Epoch 4/200
# 93/93 - 2s - loss: 0.9814 - accuracy: 0.5994 - val_loss: 1.2536 - val_accuracy: 0.5557 - 2s/epoch - 22ms/step
# Epoch 5/200
# 93/93 - 2s - loss: 0.9697 - accuracy: 0.5852 - val_loss: 27.5603 - val_accuracy: 0.3663 - 2s/epoch - 22ms/step
# Epoch 6/200
# 93/93 - 2s - loss: 0.9201 - accuracy: 0.6021 - val_loss: 6.9670 - val_accuracy: 0.4970 - 2s/epoch - 22ms/step
# Epoch 7/200
# 93/93 - 2s - loss: 0.7332 - accuracy: 0.6988 - val_loss: 2.1849 - val_accuracy: 0.4040 - 2s/epoch - 21ms/step
# Epoch 8/200
# 93/93 - 2s - loss: 0.6742 - accuracy: 0.7278 - val_loss: 0.6910 - val_accuracy: 0.7520 - 2s/epoch - 22ms/step
# Epoch 9/200
# 93/93 - 2s - loss: 0.6190 - accuracy: 0.7594 - val_loss: 0.5502 - val_accuracy: 0.7847 - 2s/epoch - 22ms/step
# Epoch 10/200
# 93/93 - 2s - loss: 0.5861 - accuracy: 0.7665 - val_loss: 0.5489 - val_accuracy: 0.7820 - 2s/epoch - 22ms/step
# Epoch 11/200
# 93/93 - 2s - loss: 0.5585 - accuracy: 0.7716 - val_loss: 0.6717 - val_accuracy: 0.7323 - 2s/epoch - 22ms/step
# Epoch 12/200
# 93/93 - 2s - loss: 0.5192 - accuracy: 0.7948 - val_loss: 0.5194 - val_accuracy: 0.7950 - 2s/epoch - 22ms/step
# Epoch 13/200
# 93/93 - 2s - loss: 0.5423 - accuracy: 0.7894 - val_loss: 0.4644 - val_accuracy: 0.8217 - 2s/epoch - 22ms/step
# Epoch 14/200
# 93/93 - 2s - loss: 0.4729 - accuracy: 0.8096 - val_loss: 0.5748 - val_accuracy: 0.7903 - 2s/epoch - 22ms/step
# Epoch 15/200
# 93/93 - 2s - loss: 0.4529 - accuracy: 0.8268 - val_loss: 0.5445 - val_accuracy: 0.7977 - 2s/epoch - 22ms/step
# Epoch 16/200
# 93/93 - 2s - loss: 0.3984 - accuracy: 0.8430 - val_loss: 0.4828 - val_accuracy: 0.8257 - 2s/epoch - 22ms/step
# Epoch 17/200
# 93/93 - 2s - loss: 0.4219 - accuracy: 0.8373 - val_loss: 0.3969 - val_accuracy: 0.8490 - 2s/epoch - 22ms/step
# Epoch 18/200
# 93/93 - 2s - loss: 0.3665 - accuracy: 0.8568 - val_loss: 0.4375 - val_accuracy: 0.8463 - 2s/epoch - 22ms/step
# Epoch 19/200
# 93/93 - 2s - loss: 0.3698 - accuracy: 0.8595 - val_loss: 0.5792 - val_accuracy: 0.7953 - 2s/epoch - 22ms/step
# Epoch 20/200
# 93/93 - 2s - loss: 0.3593 - accuracy: 0.8619 - val_loss: 0.3950 - val_accuracy: 0.8450 - 2s/epoch - 22ms/step
# Epoch 21/200
# 93/93 - 2s - loss: 0.3324 - accuracy: 0.8753 - val_loss: 0.3433 - val_accuracy: 0.8677 - 2s/epoch - 22ms/step
# Epoch 22/200
# 93/93 - 2s - loss: 0.3171 - accuracy: 0.8804 - val_loss: 0.4561 - val_accuracy: 0.8327 - 2s/epoch - 22ms/step
# Epoch 23/200
# 93/93 - 2s - loss: 0.3265 - accuracy: 0.8774 - val_loss: 0.3521 - val_accuracy: 0.8703 - 2s/epoch - 22ms/step
# Epoch 24/200
# 93/93 - 2s - loss: 0.2963 - accuracy: 0.8908 - val_loss: 0.3005 - val_accuracy: 0.8843 - 2s/epoch - 22ms/step
# Epoch 25/200
# 93/93 - 2s - loss: 0.2803 - accuracy: 0.8972 - val_loss: 0.3109 - val_accuracy: 0.8830 - 2s/epoch - 22ms/step
# Epoch 26/200
# 93/93 - 2s - loss: 0.2620 - accuracy: 0.9003 - val_loss: 0.3802 - val_accuracy: 0.8580 - 2s/epoch - 21ms/step
# Epoch 27/200
# 93/93 - 2s - loss: 0.2464 - accuracy: 0.9067 - val_loss: 0.5308 - val_accuracy: 0.8030 - 2s/epoch - 22ms/step
# Epoch 28/200
# 93/93 - 2s - loss: 0.2487 - accuracy: 0.9050 - val_loss: 0.3514 - val_accuracy: 0.8750 - 2s/epoch - 22ms/step
# Epoch 29/200
# 93/93 - 2s - loss: 0.2510 - accuracy: 0.9030 - val_loss: 0.3882 - val_accuracy: 0.8517 - 2s/epoch - 22ms/step
# Epoch 30/200
# 93/93 - 2s - loss: 0.2460 - accuracy: 0.9097 - val_loss: 0.2706 - val_accuracy: 0.9013 - 2s/epoch - 22ms/step
# Epoch 31/200
# 93/93 - 2s - loss: 0.2125 - accuracy: 0.9188 - val_loss: 0.2976 - val_accuracy: 0.8880 - 2s/epoch - 22ms/step
# Epoch 32/200
# 93/93 - 2s - loss: 0.2152 - accuracy: 0.9181 - val_loss: 0.2922 - val_accuracy: 0.8963 - 2s/epoch - 22ms/step
# Epoch 33/200
# 93/93 - 2s - loss: 0.1867 - accuracy: 0.9326 - val_loss: 0.3186 - val_accuracy: 0.8940 - 2s/epoch - 22ms/step
# Epoch 34/200
# 93/93 - 2s - loss: 0.2094 - accuracy: 0.9175 - val_loss: 0.3312 - val_accuracy: 0.8797 - 2s/epoch - 22ms/step
# Epoch 35/200
# 93/93 - 2s - loss: 0.1902 - accuracy: 0.9299 - val_loss: 0.3499 - val_accuracy: 0.8713 - 2s/epoch - 22ms/step
# Epoch 36/200
# 93/93 - 2s - loss: 0.1929 - accuracy: 0.9333 - val_loss: 0.2909 - val_accuracy: 0.8997 - 2s/epoch - 22ms/step
# Epoch 37/200
# 93/93 - 2s - loss: 0.1907 - accuracy: 0.9299 - val_loss: 0.3560 - val_accuracy: 0.8687 - 2s/epoch - 22ms/step
# Epoch 38/200
# 93/93 - 2s - loss: 0.1763 - accuracy: 0.9356 - val_loss: 0.2770 - val_accuracy: 0.9013 - 2s/epoch - 22ms/step
# Epoch 39/200
# 93/93 - 2s - loss: 0.1770 - accuracy: 0.9350 - val_loss: 0.3789 - val_accuracy: 0.8910 - 2s/epoch - 22ms/step
# Epoch 40/200
# 93/93 - 2s - loss: 0.1751 - accuracy: 0.9336 - val_loss: 0.5312 - val_accuracy: 0.8427 - 2s/epoch - 22ms/step
# Epoch 41/200
# 93/93 - 2s - loss: 0.1711 - accuracy: 0.9356 - val_loss: 0.2965 - val_accuracy: 0.9030 - 2s/epoch - 22ms/step
# Epoch 42/200
# 93/93 - 2s - loss: 0.1600 - accuracy: 0.9367 - val_loss: 0.3918 - val_accuracy: 0.8653 - 2s/epoch - 22ms/step
# Epoch 43/200
# 93/93 - 2s - loss: 0.1757 - accuracy: 0.9392 - val_loss: 0.2655 - val_accuracy: 0.9147 - 2s/epoch - 22ms/step
# Epoch 44/200
# 93/93 - 2s - loss: 0.1581 - accuracy: 0.9434 - val_loss: 0.5778 - val_accuracy: 0.8140 - 2s/epoch - 22ms/step
# Epoch 45/200
# 93/93 - 2s - loss: 0.1447 - accuracy: 0.9471 - val_loss: 0.2984 - val_accuracy: 0.8980 - 2s/epoch - 22ms/step
# Epoch 46/200
# 93/93 - 2s - loss: 0.1496 - accuracy: 0.9444 - val_loss: 0.5717 - val_accuracy: 0.8393 - 2s/epoch - 22ms/step
# Epoch 47/200
# 93/93 - 2s - loss: 0.1401 - accuracy: 0.9501 - val_loss: 0.3044 - val_accuracy: 0.8963 - 2s/epoch - 22ms/step
# Epoch 48/200
# 93/93 - 2s - loss: 0.1350 - accuracy: 0.9498 - val_loss: 0.2823 - val_accuracy: 0.9043 - 2s/epoch - 22ms/step
# Epoch 49/200
# 93/93 - 2s - loss: 0.1444 - accuracy: 0.9481 - val_loss: 0.2861 - val_accuracy: 0.9093 - 2s/epoch - 22ms/step
# Epoch 50/200
# 93/93 - 2s - loss: 0.1318 - accuracy: 0.9515 - val_loss: 0.3660 - val_accuracy: 0.8737 - 2s/epoch - 22ms/step
# Epoch 51/200
# 93/93 - 2s - loss: 0.1228 - accuracy: 0.9562 - val_loss: 0.3228 - val_accuracy: 0.8930 - 2s/epoch - 22ms/step
# Epoch 52/200
# 93/93 - 2s - loss: 0.1192 - accuracy: 0.9555 - val_loss: 0.2787 - val_accuracy: 0.9057 - 2s/epoch - 22ms/step
# Epoch 53/200
# 93/93 - 2s - loss: 0.1076 - accuracy: 0.9633 - val_loss: 0.2906 - val_accuracy: 0.8987 - 2s/epoch - 22ms/step
# Epoch 54/200
# 93/93 - 2s - loss: 0.1211 - accuracy: 0.9535 - val_loss: 0.3530 - val_accuracy: 0.8893 - 2s/epoch - 22ms/step
# Epoch 55/200
# 93/93 - 2s - loss: 0.1120 - accuracy: 0.9599 - val_loss: 0.2283 - val_accuracy: 0.9243 - 2s/epoch - 22ms/step
# Epoch 56/200
# 93/93 - 2s - loss: 0.1082 - accuracy: 0.9639 - val_loss: 0.3599 - val_accuracy: 0.8943 - 2s/epoch - 22ms/step
# Epoch 57/200
# 93/93 - 2s - loss: 0.1028 - accuracy: 0.9643 - val_loss: 0.5533 - val_accuracy: 0.8653 - 2s/epoch - 21ms/step
# Epoch 58/200
# 93/93 - 2s - loss: 0.0957 - accuracy: 0.9656 - val_loss: 0.2788 - val_accuracy: 0.9100 - 2s/epoch - 22ms/step
# Epoch 59/200
# 93/93 - 2s - loss: 0.1102 - accuracy: 0.9589 - val_loss: 0.2293 - val_accuracy: 0.9210 - 2s/epoch - 22ms/step
# Epoch 60/200
# 93/93 - 2s - loss: 0.0928 - accuracy: 0.9643 - val_loss: 0.3547 - val_accuracy: 0.9080 - 2s/epoch - 22ms/step
# Epoch 61/200
# 93/93 - 2s - loss: 0.1022 - accuracy: 0.9633 - val_loss: 0.2735 - val_accuracy: 0.9033 - 2s/epoch - 22ms/step
# Epoch 62/200
# 93/93 - 2s - loss: 0.1013 - accuracy: 0.9670 - val_loss: 0.3015 - val_accuracy: 0.8993 - 2s/epoch - 22ms/step
# Epoch 63/200
# 93/93 - 2s - loss: 0.0824 - accuracy: 0.9697 - val_loss: 0.5473 - val_accuracy: 0.8260 - 2s/epoch - 22ms/step
# Epoch 64/200
# 93/93 - 2s - loss: 0.1028 - accuracy: 0.9613 - val_loss: 0.2703 - val_accuracy: 0.9257 - 2s/epoch - 22ms/step
# Epoch 65/200
# 93/93 - 2s - loss: 0.0856 - accuracy: 0.9677 - val_loss: 0.3244 - val_accuracy: 0.9040 - 2s/epoch - 22ms/step
# Epoch 66/200
# 93/93 - 2s - loss: 0.0850 - accuracy: 0.9687 - val_loss: 0.2605 - val_accuracy: 0.9150 - 2s/epoch - 22ms/step
# Epoch 67/200
# 93/93 - 2s - loss: 0.0813 - accuracy: 0.9720 - val_loss: 0.3060 - val_accuracy: 0.9017 - 2s/epoch - 22ms/step
# Epoch 68/200
# 93/93 - 2s - loss: 0.0887 - accuracy: 0.9663 - val_loss: 0.3641 - val_accuracy: 0.9013 - 2s/epoch - 22ms/step
# Epoch 69/200
# 93/93 - 2s - loss: 0.0806 - accuracy: 0.9744 - val_loss: 0.2771 - val_accuracy: 0.9120 - 2s/epoch - 22ms/step
# Epoch 70/200
# 93/93 - 2s - loss: 0.0687 - accuracy: 0.9784 - val_loss: 0.2945 - val_accuracy: 0.9063 - 2s/epoch - 22ms/step
# Epoch 71/200
# 93/93 - 2s - loss: 0.0633 - accuracy: 0.9801 - val_loss: 0.3429 - val_accuracy: 0.9003 - 2s/epoch - 22ms/step
# Epoch 72/200
# 93/93 - 2s - loss: 0.0746 - accuracy: 0.9724 - val_loss: 0.2877 - val_accuracy: 0.9210 - 2s/epoch - 21ms/step
# Epoch 73/200
# 93/93 - 2s - loss: 0.0544 - accuracy: 0.9805 - val_loss: 0.2905 - val_accuracy: 0.9203 - 2s/epoch - 21ms/step
# Epoch 74/200
# 93/93 - 2s - loss: 0.0913 - accuracy: 0.9656 - val_loss: 0.2942 - val_accuracy: 0.9063 - 2s/epoch - 22ms/step
# Epoch 75/200
# 93/93 - 2s - loss: 0.0562 - accuracy: 0.9811 - val_loss: 0.4016 - val_accuracy: 0.9040 - 2s/epoch - 22ms/step
# Epoch 76/200
# 93/93 - 2s - loss: 0.0586 - accuracy: 0.9818 - val_loss: 0.3445 - val_accuracy: 0.9050 - 2s/epoch - 22ms/step
# Epoch 77/200
# 93/93 - 2s - loss: 0.0567 - accuracy: 0.9805 - val_loss: 0.2694 - val_accuracy: 0.9233 - 2s/epoch - 22ms/step
# Epoch 78/200
# 93/93 - 2s - loss: 0.0762 - accuracy: 0.9724 - val_loss: 0.2462 - val_accuracy: 0.9210 - 2s/epoch - 22ms/step
# Epoch 79/200
# 93/93 - 2s - loss: 0.0513 - accuracy: 0.9838 - val_loss: 0.4315 - val_accuracy: 0.9027 - 2s/epoch - 22ms/step
# Epoch 80/200
# 93/93 - 2s - loss: 0.0606 - accuracy: 0.9768 - val_loss: 0.3537 - val_accuracy: 0.9067 - 2s/epoch - 22ms/step
# Epoch 81/200
# 93/93 - 2s - loss: 0.0782 - accuracy: 0.9720 - val_loss: 0.4363 - val_accuracy: 0.8960 - 2s/epoch - 22ms/step
# Epoch 82/200
# 93/93 - 2s - loss: 0.0607 - accuracy: 0.9781 - val_loss: 0.3702 - val_accuracy: 0.9030 - 2s/epoch - 22ms/step
# Epoch 83/200
# 93/93 - 2s - loss: 0.0666 - accuracy: 0.9784 - val_loss: 0.3251 - val_accuracy: 0.9107 - 2s/epoch - 22ms/step
# Epoch 84/200
# 93/93 - 2s - loss: 0.0745 - accuracy: 0.9741 - val_loss: 0.4237 - val_accuracy: 0.8807 - 2s/epoch - 22ms/step
# Epoch 85/200
# 93/93 - 2s - loss: 0.0538 - accuracy: 0.9781 - val_loss: 0.3775 - val_accuracy: 0.8920 - 2s/epoch - 22ms/step
# Epoch 86/200
# 93/93 - 2s - loss: 0.0481 - accuracy: 0.9832 - val_loss: 0.3106 - val_accuracy: 0.9233 - 2s/epoch - 22ms/step
# Epoch 87/200
# 93/93 - 2s - loss: 0.0551 - accuracy: 0.9821 - val_loss: 0.3336 - val_accuracy: 0.9077 - 2s/epoch - 22ms/step
# Epoch 88/200
# 93/93 - 2s - loss: 0.0446 - accuracy: 0.9815 - val_loss: 0.6409 - val_accuracy: 0.8503 - 2s/epoch - 22ms/step
# Epoch 89/200
# 93/93 - 2s - loss: 0.0341 - accuracy: 0.9875 - val_loss: 0.2557 - val_accuracy: 0.9277 - 2s/epoch - 21ms/step
# Epoch 90/200
# 93/93 - 2s - loss: 0.0671 - accuracy: 0.9764 - val_loss: 0.2546 - val_accuracy: 0.9290 - 2s/epoch - 22ms/step
# Epoch 91/200
# 93/93 - 2s - loss: 0.0395 - accuracy: 0.9855 - val_loss: 0.2693 - val_accuracy: 0.9303 - 2s/epoch - 22ms/step
# Epoch 92/200
# 93/93 - 2s - loss: 0.0391 - accuracy: 0.9848 - val_loss: 0.4112 - val_accuracy: 0.8963 - 2s/epoch - 22ms/step
# Epoch 93/200
# 93/93 - 2s - loss: 0.0555 - accuracy: 0.9811 - val_loss: 0.4948 - val_accuracy: 0.8947 - 2s/epoch - 22ms/step
# Epoch 94/200
# 93/93 - 2s - loss: 0.0429 - accuracy: 0.9835 - val_loss: 0.3084 - val_accuracy: 0.9263 - 2s/epoch - 22ms/step
# Epoch 95/200
# 93/93 - 2s - loss: 0.0450 - accuracy: 0.9838 - val_loss: 0.2847 - val_accuracy: 0.9223 - 2s/epoch - 22ms/step
# Epoch 96/200
# 93/93 - 2s - loss: 0.0551 - accuracy: 0.9815 - val_loss: 0.5778 - val_accuracy: 0.8613 - 2s/epoch - 22ms/step
# Epoch 97/200
# 93/93 - 2s - loss: 0.0369 - accuracy: 0.9865 - val_loss: 0.3047 - val_accuracy: 0.9260 - 2s/epoch - 22ms/step
# Epoch 98/200
# 93/93 - 2s - loss: 0.0379 - accuracy: 0.9865 - val_loss: 0.3020 - val_accuracy: 0.9247 - 2s/epoch - 22ms/step
# Epoch 99/200
# 93/93 - 2s - loss: 0.0455 - accuracy: 0.9845 - val_loss: 0.2851 - val_accuracy: 0.9240 - 2s/epoch - 22ms/step
# Epoch 100/200
# 93/93 - 2s - loss: 0.0356 - accuracy: 0.9862 - val_loss: 0.3244 - val_accuracy: 0.9010 - 2s/epoch - 22ms/step
# Epoch 101/200
# 93/93 - 2s - loss: 0.0422 - accuracy: 0.9852 - val_loss: 0.3363 - val_accuracy: 0.9150 - 2s/epoch - 22ms/step
# Epoch 102/200
# 93/93 - 2s - loss: 0.0366 - accuracy: 0.9885 - val_loss: 0.3271 - val_accuracy: 0.9210 - 2s/epoch - 22ms/step
# Epoch 103/200
# 93/93 - 2s - loss: 0.0343 - accuracy: 0.9902 - val_loss: 0.2661 - val_accuracy: 0.9270 - 2s/epoch - 22ms/step
# Epoch 104/200
# 93/93 - 2s - loss: 0.0318 - accuracy: 0.9892 - val_loss: 0.3867 - val_accuracy: 0.8937 - 2s/epoch - 22ms/step
# Epoch 105/200
# 93/93 - 2s - loss: 0.0486 - accuracy: 0.9838 - val_loss: 0.2980 - val_accuracy: 0.9200 - 2s/epoch - 22ms/step
# Epoch 106/200
# 93/93 - 2s - loss: 0.0354 - accuracy: 0.9875 - val_loss: 0.3235 - val_accuracy: 0.9150 - 2s/epoch - 22ms/step
# Epoch 107/200
# 93/93 - 2s - loss: 0.0388 - accuracy: 0.9879 - val_loss: 0.3672 - val_accuracy: 0.9140 - 2s/epoch - 22ms/step
# Epoch 108/200
# 93/93 - 2s - loss: 0.0229 - accuracy: 0.9923 - val_loss: 0.2712 - val_accuracy: 0.9267 - 2s/epoch - 22ms/step
# Epoch 109/200
# 93/93 - 2s - loss: 0.0271 - accuracy: 0.9919 - val_loss: 0.2530 - val_accuracy: 0.9303 - 2s/epoch - 22ms/step
# Epoch 110/200
# 93/93 - 2s - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.4120 - val_accuracy: 0.9080 - 2s/epoch - 22ms/step
# Epoch 111/200
# 93/93 - 2s - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.3060 - val_accuracy: 0.9297 - 2s/epoch - 22ms/step
# Epoch 112/200
# 93/93 - 2s - loss: 0.0451 - accuracy: 0.9832 - val_loss: 0.4061 - val_accuracy: 0.9110 - 2s/epoch - 22ms/step
# Epoch 113/200
# 93/93 - 2s - loss: 0.0244 - accuracy: 0.9909 - val_loss: 0.3706 - val_accuracy: 0.9040 - 2s/epoch - 22ms/step
# Epoch 114/200
# 93/93 - 2s - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.2843 - val_accuracy: 0.9247 - 2s/epoch - 22ms/step
# Epoch 115/200
# 93/93 - 2s - loss: 0.0207 - accuracy: 0.9912 - val_loss: 0.3263 - val_accuracy: 0.9237 - 2s/epoch - 22ms/step
# Epoch 116/200
# 93/93 - 2s - loss: 0.0296 - accuracy: 0.9892 - val_loss: 0.2784 - val_accuracy: 0.9317 - 2s/epoch - 22ms/step
# Epoch 117/200
# 93/93 - 2s - loss: 0.0236 - accuracy: 0.9919 - val_loss: 0.2984 - val_accuracy: 0.9257 - 2s/epoch - 22ms/step
# Epoch 118/200
# 93/93 - 2s - loss: 0.0172 - accuracy: 0.9926 - val_loss: 0.3984 - val_accuracy: 0.9050 - 2s/epoch - 22ms/step
# Epoch 119/200
# 93/93 - 2s - loss: 0.0275 - accuracy: 0.9902 - val_loss: 0.3114 - val_accuracy: 0.9237 - 2s/epoch - 22ms/step
# Epoch 120/200
# 93/93 - 2s - loss: 0.0166 - accuracy: 0.9943 - val_loss: 0.3733 - val_accuracy: 0.9153 - 2s/epoch - 22ms/step
# Epoch 121/200
# 93/93 - 2s - loss: 0.0348 - accuracy: 0.9879 - val_loss: 0.3026 - val_accuracy: 0.9220 - 2s/epoch - 22ms/step
# Epoch 122/200
# 93/93 - 2s - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.2618 - val_accuracy: 0.9343 - 2s/epoch - 22ms/step
# Epoch 123/200
# 93/93 - 2s - loss: 0.0242 - accuracy: 0.9916 - val_loss: 0.3205 - val_accuracy: 0.9237 - 2s/epoch - 22ms/step
# Epoch 124/200
# 93/93 - 2s - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.2964 - val_accuracy: 0.9277 - 2s/epoch - 22ms/step
# Epoch 125/200
# 93/93 - 2s - loss: 0.0158 - accuracy: 0.9949 - val_loss: 0.3041 - val_accuracy: 0.9270 - 2s/epoch - 22ms/step
# Epoch 126/200
# 93/93 - 2s - loss: 0.0121 - accuracy: 0.9973 - val_loss: 0.2855 - val_accuracy: 0.9317 - 2s/epoch - 22ms/step
# Epoch 127/200
# 93/93 - 2s - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.2611 - val_accuracy: 0.9340 - 2s/epoch - 22ms/step
# Epoch 128/200
# 93/93 - 2s - loss: 0.0171 - accuracy: 0.9953 - val_loss: 0.3137 - val_accuracy: 0.9277 - 2s/epoch - 22ms/step
# Epoch 129/200
# 93/93 - 2s - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.3203 - val_accuracy: 0.9230 - 2s/epoch - 22ms/step
# Epoch 130/200
# 93/93 - 2s - loss: 0.0235 - accuracy: 0.9912 - val_loss: 0.3171 - val_accuracy: 0.9277 - 2s/epoch - 22ms/step
# Epoch 131/200
# 93/93 - 2s - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.2984 - val_accuracy: 0.9287 - 2s/epoch - 22ms/step
# Epoch 132/200
# 93/93 - 2s - loss: 0.0103 - accuracy: 0.9980 - val_loss: 0.3605 - val_accuracy: 0.9193 - 2s/epoch - 22ms/step
# Epoch 133/200
# 93/93 - 2s - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.2778 - val_accuracy: 0.9327 - 2s/epoch - 22ms/step
# Epoch 134/200
# 93/93 - 2s - loss: 0.0185 - accuracy: 0.9929 - val_loss: 0.3290 - val_accuracy: 0.9267 - 2s/epoch - 22ms/step
# Epoch 135/200
# 93/93 - 2s - loss: 0.0282 - accuracy: 0.9926 - val_loss: 0.2741 - val_accuracy: 0.9210 - 2s/epoch - 22ms/step
# Epoch 136/200
# 93/93 - 2s - loss: 0.0160 - accuracy: 0.9939 - val_loss: 0.2967 - val_accuracy: 0.9290 - 2s/epoch - 22ms/step
# Epoch 137/200
# 93/93 - 2s - loss: 0.0142 - accuracy: 0.9939 - val_loss: 0.2769 - val_accuracy: 0.9297 - 2s/epoch - 22ms/step
# Epoch 138/200
# 93/93 - 2s - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.3019 - val_accuracy: 0.9320 - 2s/epoch - 22ms/step
# Epoch 139/200
# 93/93 - 2s - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.3214 - val_accuracy: 0.9347 - 2s/epoch - 22ms/step
# Epoch 140/200
# 93/93 - 2s - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.2714 - val_accuracy: 0.9320 - 2s/epoch - 22ms/step
# Epoch 141/200
# 93/93 - 2s - loss: 0.0150 - accuracy: 0.9943 - val_loss: 0.3252 - val_accuracy: 0.9197 - 2s/epoch - 22ms/step
# Epoch 142/200
# 93/93 - 2s - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.3372 - val_accuracy: 0.9230 - 2s/epoch - 22ms/step
# Epoch 143/200
# 93/93 - 2s - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.3011 - val_accuracy: 0.9280 - 2s/epoch - 22ms/step
# Epoch 144/200
# 93/93 - 2s - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.3339 - val_accuracy: 0.9203 - 2s/epoch - 22ms/step
# Epoch 145/200
# 93/93 - 2s - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.2624 - val_accuracy: 0.9333 - 2s/epoch - 22ms/step
# Epoch 146/200
# 93/93 - 2s - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.2571 - val_accuracy: 0.9360 - 2s/epoch - 22ms/step
# Epoch 147/200
# 93/93 - 2s - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.2806 - val_accuracy: 0.9317 - 2s/epoch - 22ms/step
# Epoch 148/200
# 93/93 - 2s - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.2505 - val_accuracy: 0.9350 - 2s/epoch - 22ms/step
# Epoch 149/200
# 93/93 - 2s - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.2957 - val_accuracy: 0.9383 - 2s/epoch - 22ms/step
# Epoch 150/200
# 93/93 - 2s - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.2963 - val_accuracy: 0.9360 - 2s/epoch - 22ms/step
# Epoch 151/200
# 93/93 - 2s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.2993 - val_accuracy: 0.9357 - 2s/epoch - 22ms/step
# Epoch 152/200
# 93/93 - 2s - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.2997 - val_accuracy: 0.9350 - 2s/epoch - 22ms/step
# Epoch 153/200
# 93/93 - 2s - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.3459 - val_accuracy: 0.9250 - 2s/epoch - 22ms/step
# Epoch 154/200
# 93/93 - 2s - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.2877 - val_accuracy: 0.9333 - 2s/epoch - 22ms/step
# Epoch 155/200
# 93/93 - 2s - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.2947 - val_accuracy: 0.9317 - 2s/epoch - 22ms/step
# Epoch 156/200
# 93/93 - 2s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.2861 - val_accuracy: 0.9357 - 2s/epoch - 22ms/step
# Epoch 157/200
# 93/93 - 2s - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.3538 - val_accuracy: 0.9217 - 2s/epoch - 22ms/step
# Epoch 158/200
# 93/93 - 2s - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.2969 - val_accuracy: 0.9320 - 2s/epoch - 22ms/step
# Epoch 159/200
# 93/93 - 2s - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.2985 - val_accuracy: 0.9367 - 2s/epoch - 22ms/step
# Epoch 160/200
# 93/93 - 2s - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.2744 - val_accuracy: 0.9373 - 2s/epoch - 22ms/step
# Epoch 161/200
# 93/93 - 2s - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.2963 - val_accuracy: 0.9350 - 2s/epoch - 22ms/step
# Epoch 162/200
# 93/93 - 2s - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.2683 - val_accuracy: 0.9350 - 2s/epoch - 22ms/step
# Epoch 163/200
# 93/93 - 2s - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.2635 - val_accuracy: 0.9377 - 2s/epoch - 22ms/step
# Epoch 164/200
# 93/93 - 2s - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.2643 - val_accuracy: 0.9383 - 2s/epoch - 22ms/step
# Epoch 165/200
# 93/93 - 2s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.2428 - val_accuracy: 0.9380 - 2s/epoch - 22ms/step
# Epoch 166/200
# 93/93 - 2s - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.2603 - val_accuracy: 0.9377 - 2s/epoch - 22ms/step
# Epoch 167/200
# 93/93 - 2s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9370 - 2s/epoch - 22ms/step
# Epoch 168/200
# 93/93 - 2s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.2618 - val_accuracy: 0.9387 - 2s/epoch - 22ms/step
# Epoch 169/200
# 93/93 - 2s - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.2839 - val_accuracy: 0.9343 - 2s/epoch - 22ms/step
# Epoch 170/200
# 93/93 - 2s - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.2520 - val_accuracy: 0.9387 - 2s/epoch - 22ms/step
# Epoch 171/200
# 93/93 - 2s - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.2621 - val_accuracy: 0.9367 - 2s/epoch - 22ms/step
# Epoch 172/200
# 93/93 - 2s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.2649 - val_accuracy: 0.9387 - 2s/epoch - 22ms/step
# Epoch 173/200
# 93/93 - 2s - loss: 9.9453e-04 - accuracy: 1.0000 - val_loss: 0.2716 - val_accuracy: 0.9387 - 2s/epoch - 22ms/step
# Epoch 174/200
# 93/93 - 2s - loss: 7.9070e-04 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9393 - 2s/epoch - 22ms/step
# Epoch 175/200
# 93/93 - 2s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.2635 - val_accuracy: 0.9397 - 2s/epoch - 22ms/step
# Epoch 176/200
# 93/93 - 2s - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.2690 - val_accuracy: 0.9383 - 2s/epoch - 22ms/step
# Epoch 177/200
# 93/93 - 2s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.2595 - val_accuracy: 0.9390 - 2s/epoch - 21ms/step
# Epoch 178/200
# 93/93 - 2s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2610 - val_accuracy: 0.9387 - 2s/epoch - 22ms/step
# Epoch 179/200
# 93/93 - 2s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2636 - val_accuracy: 0.9387 - 2s/epoch - 22ms/step
# Epoch 180/200
# 93/93 - 2s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2511 - val_accuracy: 0.9413 - 2s/epoch - 22ms/step
# Epoch 181/200
# 93/93 - 2s - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.2439 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step
# Epoch 182/200
# 93/93 - 2s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2463 - val_accuracy: 0.9413 - 2s/epoch - 23ms/step
# Epoch 183/200
# 93/93 - 2s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2484 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step
# Epoch 184/200
# 93/93 - 2s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.2456 - val_accuracy: 0.9397 - 2s/epoch - 22ms/step
# Epoch 185/200
# 93/93 - 2s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.2464 - val_accuracy: 0.9403 - 2s/epoch - 22ms/step
# Epoch 186/200
# 93/93 - 2s - loss: 7.8418e-04 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9410 - 2s/epoch - 22ms/step
# Epoch 187/200
# 93/93 - 2s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2438 - val_accuracy: 0.9410 - 2s/epoch - 22ms/step
# Epoch 188/200
# 93/93 - 2s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.2421 - val_accuracy: 0.9410 - 2s/epoch - 22ms/step
# Epoch 189/200
# 93/93 - 2s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2409 - val_accuracy: 0.9410 - 2s/epoch - 22ms/step
# Epoch 190/200
# 93/93 - 2s - loss: 8.1402e-04 - accuracy: 1.0000 - val_loss: 0.2395 - val_accuracy: 0.9413 - 2s/epoch - 23ms/step
# Epoch 191/200
# 93/93 - 2s - loss: 9.8109e-04 - accuracy: 1.0000 - val_loss: 0.2380 - val_accuracy: 0.9410 - 2s/epoch - 22ms/step
# Epoch 192/200
# 93/93 - 2s - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.2362 - val_accuracy: 0.9413 - 2s/epoch - 22ms/step
# Epoch 193/200
# 93/93 - 2s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.2365 - val_accuracy: 0.9410 - 2s/epoch - 22ms/step
# Epoch 194/200
# 93/93 - 2s - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.2347 - val_accuracy: 0.9410 - 2s/epoch - 22ms/step
# Epoch 195/200
# 93/93 - 2s - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.2336 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step
# Epoch 196/200
# 93/93 - 2s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2334 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step
# Epoch 197/200
# 93/93 - 2s - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.2315 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step
# Epoch 198/200
# 93/93 - 2s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step
# Epoch 199/200
# 93/93 - 2s - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.2281 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step
# Epoch 200/200
# 93/93 - 2s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9407 - 2s/epoch - 22ms/step

# %%
model.save("VGG_16.h5")
